# %%
import numpy as np
from suite2p import run_s2p
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# set options for running
ops =  np.load('C:/Users/nnguyen/.suite2p/ops/ops_user.npy', allow_pickle=True)
ops = list(enumerate(ops.flatten(), 1))
ops = ops[0][1]

# %%
# make a list of db's and loop over them
db = []

mouse = 'NN9'
date = '210501'
db.append({'data_path': ['D:/2p_data/scan/' + mouse + '/' + date + '_' + mouse + '/suite2p_plane_1']})
db.append({'data_path': ['D:/2p_data/scan/' + mouse + '/' + date + '_' + mouse + '/suite2p_plane_2']})
db.append({'data_path': ['D:/2p_data/scan/' + mouse + '/' + date + '_' + mouse + '/suite2p_plane_3']})

for dbi in db:
    opsEnd = run_s2p(ops=ops, db=dbi)
# Out:
# {'data_path': ['D:/2p_data/scan/NN9/210501_NN9/suite2p_plane_1']}
# tif
# ** Found 25 tifs - converting to binary **
# 2000 frames of binary, time 17.70 sec.
# 4000 frames of binary, time 31.01 sec.
# 6000 frames of binary, time 46.23 sec.
# 8000 frames of binary, time 58.90 sec.
# 10000 frames of binary, time 71.52 sec.
# 12000 frames of binary, time 86.66 sec.
# 14000 frames of binary, time 99.82 sec.
# 16000 frames of binary, time 115.67 sec.
# 18000 frames of binary, time 128.62 sec.
# 20000 frames of binary, time 141.62 sec.
# time 727.60 sec. Wrote 106665 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 106665 frames
# Reference frame, 151.43 sec.
# Registered 2000/106665 in 170.10s
# Registered 4000/106665 in 326.89s
# Registered 6000/106665 in 484.81s
# ...
